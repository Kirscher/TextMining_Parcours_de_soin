# %% [markdown]
# # Exploratory Data Analysis - Patient, consommant et hospitalisation

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
patient=pd.read_csv("patient_anonyme.csv")
hospit_non_chr=pd.read_csv("base_hospit_non_chr_anonyme.csv")
# Out:
# /tmp/ipykernel_1040/1855722776.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   hospit_non_chr=pd.read_csv("base_hospit_non_chr_anonyme.csv")

# %% [markdown]
# ## Description de la population (base patient)

# %%
patient.head()
# Out:
#       date_h0  ALD_before  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces  \
# 0  2011-11-22           0    1949          11            1       NaN
# 1  2013-12-05           0    1929          14            2   2015-03
# 2  2015-07-02           0    1967          54            2   2015-08
# 3  2011-05-19           0    1959         974            1       NaN
# 4  2010-03-18           0    1947          76            1       NaN
#
#   CODE_PATIENT   Mort  Nb_survie
# 0           P0  False       2596
# 1           P6   True        456
# 2           P8   True         41
# 3          P13  False       2783
# 4          P16  False       3210

# %%
patient.describe()
# Out:
#        ALD_before        y_nais   BEN_SEX_COD     Nb_survie
# count     10052.0  10052.000000  10052.000000  10052.000000
# mean          0.0   1934.601870      1.512037   1130.750398
# std           0.0     13.537071      0.499880    951.323657
# min           0.0   1907.000000      1.000000      0.000000
# 25%           0.0   1925.000000      1.000000    171.000000
# 50%           0.0   1931.000000      2.000000   1101.000000
# 75%           0.0   1942.000000      2.000000   1836.000000
# max           0.0   1997.000000      2.000000   3384.000000

# %%
# Out:
#                  date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# CODE_PATIENT
# P8            2015-07-02    1967          54            2   2015-08   True
# P13           2011-05-19    1959         974            1       NaN  False
# P23           2012-11-30    1966          62            2       NaN  False
# P24           2012-02-13    1967          86            1   2018-12   True
# P25           2014-01-07    1975          57            1       NaN  False
# ...                  ...     ...         ...          ...       ...    ...
# P24186        2015-06-14    1969          47            1   2015-06   True
# P24192        2015-09-24    1979          93            1       NaN  False
# P24210        2011-05-05    1958         999            2   2014-01   True
# P24218        2014-11-19    1970          59            1   2015-08   True
# P24234        2013-06-12    1956          54            1       NaN  False
#
#               Nb_survie  Nb_hospit   CHOC  Nb_jours_sej
# CODE_PATIENT
# P8                   41          3   True            43
# P13                2783          2  False             3
# P23                2222          9  False            24
# P24                2489         20  False            41
# P25                1819         10  False            36
# ...                 ...        ...    ...           ...
# P24186                0          3  False             3
# P24192             1194          3  False             2
# P24210              990          7  False            22
# P24218              255         24  False           107
# P24234             2028          7  False            20
#
# [1118 rows x 10 columns]

# %%
# Out:
#                  date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# CODE_PATIENT
# P6            2013-12-05    1929          14            2   2015-03   True
# P17           2015-02-02    1933          35            2   2017-07   True
# P19           2011-07-07    1933          24            2   2014-01   True
# P30           2011-07-27    1930          37            1   2015-12   True
# P39           2015-07-13    1920          75            2   2016-04   True
# ...                  ...     ...         ...          ...       ...    ...
# P24286        2015-04-03    1931          36            1       NaN  False
# P24302        2014-02-08    1920          29            1   2014-12   True
# P24303        2012-02-09    1927          61            1   2017-05   True
# P24304        2010-07-27    1924         999            1   2010-08   True
# P24308        2011-11-25    1925          13            2   2013-03   True
#
#               Nb_survie  Nb_hospit   CHOC  Nb_jours_sej
# CODE_PATIENT
# P6                  456          8  False            51
# P17                 905         34  False           260
# P19                 938          8  False            95
# P30                1606         22  False           131
# P39                 263          5  False            21
# ...                 ...        ...    ...           ...
# P24286             1368          6  False            35
# P24302              318          8  False            47
# P24303             1924         12  False            86
# P24304                5          1  False            10
# P24308              484          7  False            99
#
# [5764 rows x 10 columns]

# %% [markdown]
# ### Âges, sexes, et décès des patients

# %%
fig, ax = f, ax = plt.subplots()
fig.set_size_inches(8, 4)
sns.histplot(data=patient, x="y_nais", kde=True, ax=ax)
ax.axvline(x=patient.y_nais.median(), color='r', label='median')
ax.axvline(x=patient.y_nais.quantile(.25), color='r', linestyle='--', label='q0.25')
ax.axvline(x=patient.y_nais.quantile(.75), color='r', linestyle='-.', label='q0.75')
ax.set_xlabel("Année de naissance")
fig.suptitle("Distribution des années de naissance des patients")
fig.legend(loc=5)

# %%
fig, ax = f, ax = plt.subplots()
fig.set_size_inches(8, 4)
sns.histplot(patient, x="y_nais", hue="Mort",
            kde=True,
            ax=ax,
            #stat="probability"
           )
ax.axvline(x=patient[patient["Mort"]==True].y_nais.median(), color='orange', label='median dead')
ax.axvline(x=patient[patient["Mort"]==False].y_nais.median(), color='blue', label='median alive')
ax.set_xlabel("Année de naissance")
fig.suptitle("Distribution des années de naissance des patients")
fig.legend(loc=5)

# %%
patient[patient['Mort']==False].describe()
# Out:
#        ALD_before       y_nais  BEN_SEX_COD    Nb_survie
# count      3433.0  3433.000000  3433.000000  3433.000000
# mean          0.0  1941.572094     1.489077  2033.184678
# std           0.0    14.469971     0.499953   624.998717
# min           0.0  1908.000000     1.000000  1096.000000
# 25%           0.0  1931.000000     1.000000  1468.000000
# 50%           0.0  1938.000000     1.000000  1951.000000
# 75%           0.0  1951.000000     2.000000  2545.000000
# max           0.0  1997.000000     2.000000  3286.000000

# %% [markdown]
# + L'année de naissance *moyenne* des patients qui ne sont pas décédés est : **1941**
# + L'année de naissance *médiane* des patients qui ne sont pas décédés est : **1938**

# %%
patient[patient['Mort']==True].describe()
# Out:
#        ALD_before       y_nais  BEN_SEX_COD    Nb_survie
# count      6619.0  6619.000000  6619.000000  6619.000000
# mean          0.0  1930.986705     1.523946   662.695271
# std           0.0    11.465459     0.499464   728.250595
# min           0.0  1907.000000     1.000000     0.000000
# 25%           0.0  1923.000000     1.000000    48.500000
# 50%           0.0  1928.000000     2.000000   388.000000
# 75%           0.0  1936.000000     2.000000  1082.000000
# max           0.0  1994.000000     2.000000  3384.000000

# %% [markdown]
# + L'année de naissance *moyenne* des patients décédés est : **1930**
# + L'année de naissance *médiane* des patients décédés est : **1928**

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
fig.set_size_inches(8, 8)

sns.countplot(x="BEN_SEX_COD", data=patient, ax=ax1)
ax1.set_title("Sexe des patients (1: homme | 2: femme)")
ax1.bar_label(ax1.containers[0])
ax1.set_xlabel("Sexe")

sns.countplot(x="BEN_SEX_COD", hue="Mort", data=patient, ax=ax2)
ax2.set_xlabel("Sexe")
ax2.bar_label(ax2.containers[0])
ax2.bar_label(ax2.containers[1])

plt.show()

# %% [markdown]
# Le dataset est plutôt équilibré avec :
# + 5147 femmes (**51.2%** de la population totale)
# + 4905 hommes (**48.8%** de la population totale)
#
# Concernant les patients décédés (6619, **66%** de la population totale) :
# + 3468 femmes (**52.4%** de la population décédée)
# + 3151 hommes (**47.6%** de la population décédée)
#
# Concernant les patients en vie à la fin de l'étude (3433, **34%** de la population totale) :
# + 1679 femmes (**52.4%** de la population décédée)
# + 1754 hommes (**47.6%** de la population décédée)

# %%
plt.figure(figsize=(10,2))
sns.catplot(data=patient, x="Mort", y="y_nais", hue="BEN_SEX_COD", kind="box")

# %% [markdown]
# ### Etude de la variable Nb_survie

# %%
sns.jointplot(data=patient, x="y_nais", y="Nb_survie", hue="Mort")

# %%
data=patient[patient["Mort"]==True]
titre="Distribution du nombre de jours de survie des patients décédés, en fonction de l'âge initial"
g=sns.displot(data, x="y_nais", y="Nb_survie", cbar=True,
            #kind="kde",
           ).set(title=titre)
g.set_axis_labels("Année de naissance")

# %% [markdown]
# ## Ajout des hospitalisations (base hospitalisations non chroniques)

# %% [markdown]
# ### Ajout du nombre d'hospitalisations pour chaque patient

# %%
hospit_non_chr.head()
# Out:
#   RSA_NUM    ETA_NUM EXE_SOI_DTD  SEJ_NBJ GRG_GHM DGN_PAL DGN_REL BEN_NIR_IDT  \
# 0  144689  310781406  2011-11-22      2.0  05K051   I2100     NaN          P0
# 1    2763  110780061  2011-11-24      8.0  05M042  I21000     NaN          P0
# 2   15548  110780061  2011-12-08      0.0  05M16T    I255     NaN          P0
# 3    5260  110780061  2012-03-04      1.0  05M09T    I501     NaN          P0
# 4  112258  310781406  2012-03-05      7.0  05M092    I501     NaN          P0
#
#     Mort  Nb_survie  CHOC  HEMOD  CHIMIO  Radiotherapie  Transfusion
# 0  False       2596     0      0       0              0            0
# 1  False       2596     0      0       0              0            0
# 2  False       2596     0      0       0              0            0
# 3  False       2596     0      0       0              0            0
# 4  False       2596     0      0       0              0            0

# %%
hospit=hospit_non_chr.groupby("BEN_NIR_IDT").count()[['RSA_NUM']].reset_index()
hospit=hospit.rename(columns={"BEN_NIR_IDT": "CODE_PATIENT", "RSA_NUM": "Nb_hospit"})

# %%
hospit=hospit.set_index("CODE_PATIENT")
hospit.head()
# Out:
#               Nb_hospit
# CODE_PATIENT
# P0                    9
# P10001                9
# P10003                3
# P10004                8
# P10006                1

# %%
patient=patient.set_index("CODE_PATIENT")
patient["Nb_hospit"]=hospit["Nb_hospit"]
patient=patient.drop("ALD_before", axis=1)
patient.head()
# Out:
#                  date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# CODE_PATIENT
# P0            2011-11-22    1949          11            1       NaN  False
# P6            2013-12-05    1929          14            2   2015-03   True
# P8            2015-07-02    1967          54            2   2015-08   True
# P13           2011-05-19    1959         974            1       NaN  False
# P16           2010-03-18    1947          76            1       NaN  False
#
#               Nb_survie  Nb_hospit
# CODE_PATIENT
# P0                 2596        9.0
# P6                  456        8.0
# P8                   41        3.0
# P13                2783        2.0
# P16                3210        9.0

# %% [markdown]
# ### Ajout des chocs

# %%
hospit_choc=hospit_non_chr.groupby("BEN_NIR_IDT").sum()[["CHOC"]]
# Out:
# /tmp/ipykernel_1040/1420949653.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   hospit_choc=hospit_non_chr.groupby("BEN_NIR_IDT").sum()[["CHOC"]]

# %%
patient["CHOC"]=hospit_choc["CHOC"]>0

# %%
patient.head()
# Out:
#                  date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# CODE_PATIENT
# P0            2011-11-22    1949          11            1       NaN  False
# P6            2013-12-05    1929          14            2   2015-03   True
# P8            2015-07-02    1967          54            2   2015-08   True
# P13           2011-05-19    1959         974            1       NaN  False
# P16           2010-03-18    1947          76            1       NaN  False
#
#               Nb_survie  Nb_hospit   CHOC
# CODE_PATIENT
# P0                 2596        9.0  False
# P6                  456        8.0  False
# P8                   41        3.0   True
# P13                2783        2.0  False
# P16                3210        9.0  False

# %%
patient.describe()
# Out:
#              y_nais   BEN_SEX_COD     Nb_survie     Nb_hospit
# count  10052.000000  10052.000000  10052.000000  10051.000000
# mean    1934.601870      1.512037   1130.750398      8.515969
# std       13.537071      0.499880    951.323657      8.324717
# min     1907.000000      1.000000      0.000000      1.000000
# 25%     1925.000000      1.000000    171.000000      4.000000
# 50%     1931.000000      2.000000   1101.000000      7.000000
# 75%     1942.000000      2.000000   1836.000000     11.000000
# max     1997.000000      2.000000   3384.000000    255.000000

# %% [markdown]
# ### Ajout du nombre de jours d'hospitalisations

# %%
hospit_Nb_jours_sej=hospit_non_chr.groupby("BEN_NIR_IDT").sum()[["SEJ_NBJ"]]
hospit_Nb_jours_sej
# Out:
# /tmp/ipykernel_1040/866682408.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   hospit_Nb_jours_sej=hospit_non_chr.groupby("BEN_NIR_IDT").sum()[["SEJ_NBJ"]]
#              SEJ_NBJ
# BEN_NIR_IDT
# P0              23.0
# P10001          55.0
# P10003          26.0
# P10004          73.0
# P10006          22.0
# ...              ...
# P9984           10.0
# P9985            6.0
# P9987          187.0
# P999            13.0
# P9998           87.0
#
# [10051 rows x 1 columns]

# %%
patient["Nb_jours_sej"]=hospit_Nb_jours_sej["SEJ_NBJ"]

# %%
patient.head()
# Out:
#                  date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# CODE_PATIENT
# P0            2011-11-22    1949          11            1       NaN  False
# P6            2013-12-05    1929          14            2   2015-03   True
# P8            2015-07-02    1967          54            2   2015-08   True
# P13           2011-05-19    1959         974            1       NaN  False
# P16           2010-03-18    1947          76            1       NaN  False
#
#               Nb_survie  Nb_hospit   CHOC  Nb_jours_sej
# CODE_PATIENT
# P0                 2596        9.0  False          23.0
# P6                  456        8.0  False          51.0
# P8                   41        3.0   True          43.0
# P13                2783        2.0  False           3.0
# P16                3210        9.0  False          28.0

# %%
patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10052 entries, P0 to P24310
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date_h0       10052 non-null  object
#  1   y_nais        10052 non-null  int64
#  2   BEN_RES_DPT   10052 non-null  object
#  3   BEN_SEX_COD   10052 non-null  int64
#  4   dte_deces     6619 non-null   object
#  5   Mort          10052 non-null  bool
#  6   Nb_survie     10052 non-null  int64
#  7   Nb_hospit     10051 non-null  float64
#  8   CHOC          10051 non-null  object
#  9   Nb_jours_sej  10051 non-null  float64
# dtypes: bool(1), float64(2), int64(3), object(4)
# memory usage: 795.1+ KB

# %%
patient=patient[patient['Nb_hospit'].notna()]

# %%
patient['Nb_hospit']=patient['Nb_hospit'].astype(int)
patient['Nb_jours_sej']=patient['Nb_jours_sej'].astype(int)
# Out:
# CODE_PATIENT
# P0        23
# P6        51
# P8        43
# P13        3
# P16       28
#           ..
# P24302    47
# P24303    86
# P24304    10
# P24308    99
# P24310    29
# Name: Nb_jours_sej, Length: 10051, dtype: int64

# %%
patient.describe()
# Out:
#              y_nais   BEN_SEX_COD     Nb_survie     Nb_hospit  Nb_jours_sej
# count  10051.000000  10051.000000  10051.000000  10051.000000  10051.000000
# mean    1934.603622      1.511989   1130.839518      8.515969     58.271117
# std       13.536605      0.499881    951.329021      8.324717     53.318980
# min     1907.000000      1.000000      0.000000      1.000000      0.000000
# 25%     1925.000000      1.000000    171.000000      4.000000     23.000000
# 50%     1931.000000      2.000000   1101.000000      7.000000     44.000000
# 75%     1942.000000      2.000000   1836.000000     11.000000     77.000000
# max     1997.000000      2.000000   3384.000000    255.000000    808.000000

# %%
sns.boxplot(data=patient, x="Nb_survie")
# Out:
# <AxesSubplot: xlabel='Nb_survie'>

# %% [markdown]
# ## Corrélations

# %%
patient.corr()
# Out:
# /tmp/ipykernel_1040/1579629715.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   patient.corr()
#                 y_nais  BEN_SEX_COD      Mort  Nb_survie  Nb_hospit  \
# y_nais        1.000000    -0.236897 -0.370786   0.276139   0.234367
# BEN_SEX_COD  -0.236897     1.000000  0.033014  -0.017777  -0.058825
# Mort         -0.370786     0.033014  1.000000  -0.683183  -0.077668
# Nb_survie     0.276139    -0.017777 -0.683183   1.000000   0.207940
# Nb_hospit     0.234367    -0.058825 -0.077668   0.207940   1.000000
# Nb_jours_sej  0.077312    -0.004921  0.118114   0.080812   0.625425
#
#               Nb_jours_sej
# y_nais            0.077312
# BEN_SEX_COD      -0.004921
# Mort              0.118114
# Nb_survie         0.080812
# Nb_hospit         0.625425
# Nb_jours_sej      1.000000

# %%
heatmap = sns.heatmap(patient.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap')
# Out:
# /tmp/ipykernel_1040/255221680.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(patient.corr(), vmin=-1, vmax=1, annot=True)
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# + **Sexe et décès très peu corrélés** (0.033)
# + Forte corrélation (attendue) entre les variables *Mort* et *Nb_survie* (-0.68)
# + Corrélation importante (attendue) entre *Mort* et *y_nais* (-0.37)

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(patient)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %% [markdown]
# ## Création des contextes patient

# %% [markdown]
# ### Catégories d'âge

# %% [markdown]
# L’insuffisance cardiaque **touche essentiellement les personnes âgées de plus de 75 ans** (source: vidal.fr) <br>
# En France plus de 1,5 million de personnes sont atteintes d’insuffisance cardiaque, en particulier les plus de 60 ans. (source: ameli.fr) <br>
# On choisit de diviser la population en **trois catégories d'âge** distinctes :
# + les patients de plus de 85 ans
# + les patients ayant entre 65 et 85 ans
# + les patients de moins de 65 ans

# %%
# %%capture capt
patient['cat_age']=patient['y_nais'].apply(lambda x: 0 if x>=1953 else 2 if x<=1933 else 1)

# %%
patient
# Out:
#                  date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# CODE_PATIENT
# P0            2011-11-22    1949          11            1       NaN  False
# P6            2013-12-05    1929          14            2   2015-03   True
# P8            2015-07-02    1967          54            2   2015-08   True
# P13           2011-05-19    1959         974            1       NaN  False
# P16           2010-03-18    1947          76            1       NaN  False
# ...                  ...     ...         ...          ...       ...    ...
# P24302        2014-02-08    1920          29            1   2014-12   True
# P24303        2012-02-09    1927          61            1   2017-05   True
# P24304        2010-07-27    1924         999            1   2010-08   True
# P24308        2011-11-25    1925          13            2   2013-03   True
# P24310        2010-12-18    1941          81            2       NaN  False
#
#               Nb_survie  Nb_hospit   CHOC  Nb_jours_sej  cat_age
# CODE_PATIENT
# P0                 2596          9  False            23        1
# P6                  456          8  False            51        2
# P8                   41          3   True            43        0
# P13                2783          2  False             3        0
# P16                3210          9  False            28        1
# ...                 ...        ...    ...           ...      ...
# P24302              318          8  False            47        2
# P24303             1924         12  False            86        2
# P24304                5          1  False            10        2
# P24308              484          7  False            99        2
# P24310             2935          4  False            29        1
#
# [10051 rows x 11 columns]

# %%
sns.catplot(data=patient, x="Mort", y="y_nais", hue="cat_age")

# %% [markdown]
# ## Nombre d'hospitalisations

# %% [markdown]
# On choisit de diviser la population en **trois catégories** distinctes :
# + les patients n'ayant qu'une seule hospitalisation
# + les patients ayant entre 2 et 11 hospitalisations (compris)
# + les patients ayant plus de 11 hospitalisations

# %%
patient[["Nb_hospit","Nb_survie","Nb_jours_sej"]].quantile([.04,.1,.25,.5,.75,.9,.95])
# Out:
#       Nb_hospit  Nb_survie  Nb_jours_sej
# 0.04        1.0        3.0           5.0
# 0.10        2.0       15.0          11.0
# 0.25        4.0      171.0          23.0
# 0.50        7.0     1101.0          44.0
# 0.75       11.0     1836.0          77.0
# 0.90       16.0     2548.0         120.0
# 0.95       22.0     2869.0         158.0

# %%
patient['cat_nb_hospit']=patient['Nb_hospit'].apply(lambda x: 0 if x<2 else 2 if x>11 else 1)

# %% [markdown]
# ## Nombre de jours d'hospitalisations

# %% [markdown]
# On choisit de diviser la population en **trois catégories** distinctes :
# + les patients ayant moins de 5 jours d'hospitalisation
# + les patients ayant entre 5 et 70 jours d'hospitalisations (compris)
# + les patients ayant plus de 70 jours d'hospitalisations

# %%
patient['cat_nb_jours_sej']=patient['Nb_jours_sej'].apply(lambda x: 0 if x<5 else 2 if x>70 else 1)

# %%
patient
# Out:
#                  date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# CODE_PATIENT
# P0            2011-11-22    1949          11            1       NaN  False
# P6            2013-12-05    1929          14            2   2015-03   True
# P8            2015-07-02    1967          54            2   2015-08   True
# P13           2011-05-19    1959         974            1       NaN  False
# P16           2010-03-18    1947          76            1       NaN  False
# ...                  ...     ...         ...          ...       ...    ...
# P24302        2014-02-08    1920          29            1   2014-12   True
# P24303        2012-02-09    1927          61            1   2017-05   True
# P24304        2010-07-27    1924         999            1   2010-08   True
# P24308        2011-11-25    1925          13            2   2013-03   True
# P24310        2010-12-18    1941          81            2       NaN  False
#
#               Nb_survie  Nb_hospit   CHOC  Nb_jours_sej  cat_age  \
# CODE_PATIENT
# P0                 2596          9  False            23        1
# P6                  456          8  False            51        2
# P8                   41          3   True            43        0
# P13                2783          2  False             3        0
# P16                3210          9  False            28        1
# ...                 ...        ...    ...           ...      ...
# P24302              318          8  False            47        2
# P24303             1924         12  False            86        2
# P24304                5          1  False            10        2
# P24308              484          7  False            99        2
# P24310             2935          4  False            29        1
#
#               cat_nb_hospit  cat_nb_jours_sej
# CODE_PATIENT
# P0                        1                 1
# P6                        1                 1
# P8                        1                 1
# P13                       1                 0
# P16                       1                 1
# ...                     ...               ...
# P24302                    1                 1
# P24303                    2                 2
# P24304                    0                 1
# P24308                    1                 2
# P24310                    1                 1
#
# [10051 rows x 13 columns]

# %%
dic_cluster = {}
clusters = []
v = 0
for i in range(len(patient)):
    row=patient.iloc[i]
    cats = str(row.BEN_SEX_COD) + str(row.cat_age) + str(row.cat_nb_hospit)
    if dic_cluster.get(cats) != None:
        clusters.append(dic_cluster[cats])
    else:
        dic_cluster[cats] = v
        clusters.append(v)
        v+=1

# %%
dic_cluster
# Out:
# {'111': 0,
#  '221': 1,
#  '201': 2,
#  '101': 3,
#  '222': 4,
#  '102': 5,
#  '122': 6,
#  '211': 7,
#  '212': 8,
#  '112': 9,
#  '220': 10,
#  '210': 11,
#  '121': 12,
#  '120': 13,
#  '100': 14,
#  '202': 15,
#  '110': 16,
#  '200': 17}

# %%
patient['cluster'] = clusters

# %%
patient
# Out:
#                  date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# CODE_PATIENT
# P0            2011-11-22    1949          11            1       NaN  False
# P6            2013-12-05    1929          14            2   2015-03   True
# P8            2015-07-02    1967          54            2   2015-08   True
# P13           2011-05-19    1959         974            1       NaN  False
# P16           2010-03-18    1947          76            1       NaN  False
# ...                  ...     ...         ...          ...       ...    ...
# P24302        2014-02-08    1920          29            1   2014-12   True
# P24303        2012-02-09    1927          61            1   2017-05   True
# P24304        2010-07-27    1924         999            1   2010-08   True
# P24308        2011-11-25    1925          13            2   2013-03   True
# P24310        2010-12-18    1941          81            2       NaN  False
#
#               Nb_survie  Nb_hospit   CHOC  Nb_jours_sej  cat_age  \
# CODE_PATIENT
# P0                 2596          9  False            23        1
# P6                  456          8  False            51        2
# P8                   41          3   True            43        0
# P13                2783          2  False             3        0
# P16                3210          9  False            28        1
# ...                 ...        ...    ...           ...      ...
# P24302              318          8  False            47        2
# P24303             1924         12  False            86        2
# P24304                5          1  False            10        2
# P24308              484          7  False            99        2
# P24310             2935          4  False            29        1
#
#               cat_nb_hospit  cat_nb_jours_sej  cluster
# CODE_PATIENT
# P0                        1                 1        0
# P6                        1                 1        1
# P8                        1                 1        2
# P13                       1                 0        3
# P16                       1                 1        0
# ...                     ...               ...      ...
# P24302                    1                 1       12
# P24303                    2                 2        6
# P24304                    0                 1       13
# P24308                    1                 2        1
# P24310                    1                 1        7
#
# [10051 rows x 14 columns]

# %%
patient[patient["cluster"]==2]
# Out:
#                  date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# CODE_PATIENT
# P8            2015-07-02    1967          54            2   2015-08   True
# P23           2012-11-30    1966          62            2       NaN  False
# P101          2011-02-07    1955         999            2   2011-02   True
# P357          2015-03-05    1955          66            2   2015-03   True
# P411          2012-10-29    1964         999            2   2012-11   True
# ...                  ...     ...         ...          ...       ...    ...
# P23696        2010-10-04    1955          34            2       NaN  False
# P23721        2015-04-13    1954          85            2       NaN  False
# P23784        2015-07-08    1965          57            2       NaN  False
# P23912        2011-01-07    1959         999            2   2011-01   True
# P24210        2011-05-05    1958         999            2   2014-01   True
#
#               Nb_survie  Nb_hospit   CHOC  Nb_jours_sej  cat_age  \
# CODE_PATIENT
# P8                   41          3   True            43        0
# P23                2222          9  False            24        0
# P101                  0          2   True             0        0
# P357                  9          6  False            38        0
# P411                  6          4  False            42        0
# ...                 ...        ...    ...           ...      ...
# P23696             3010          6  False            13        0
# P23721             1358          9  False            35        0
# P23784             1272          4  False            11        0
# P23912                1          3   True            14        0
# P24210              990          7  False            22        0
#
#               cat_nb_hospit  cat_nb_jours_sej  cluster
# CODE_PATIENT
# P8                        1                 1        2
# P23                       1                 1        2
# P101                      1                 0        2
# P357                      1                 1        2
# P411                      1                 1        2
# ...                     ...               ...      ...
# P23696                    1                 1        2
# P23721                    1                 1        2
# P23784                    1                 1        2
# P23912                    1                 1        2
# P24210                    1                 1        2
#
# [241 rows x 14 columns]

# %%
patient.to_csv("./data/profil_patient.csv")
