# %%
#Import des librairies

import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
import plotly.express as px

# %%
# %%capture capt
p_soins=pd.read_csv("./data/p_soins_GHM.csv", index_col=0)
patients=pd.read_csv("./data/profil_patient.csv")

p_soins=p_soins.rename(columns={'0':'CODE_PATIENT'})

p_soins=p_soins.set_index('CODE_PATIENT')
patients=patients.set_index('CODE_PATIENT')

# %%
patients.head()
# Out:
#                  date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# CODE_PATIENT
# P0            2011-11-22    1949          11            1       NaN  False
# P6            2013-12-05    1929          14            2   2015-03   True
# P8            2015-07-02    1967          54            2   2015-08   True
# P13           2011-05-19    1959         974            1       NaN  False
# P16           2010-03-18    1947          76            1       NaN  False
#
#               Nb_survie  Nb_hospit   CHOC  Nb_jours_sej  cat_age  \
# CODE_PATIENT
# P0                 2596          9  False            23        1
# P6                  456          8  False            51        2
# P8                   41          3   True            43        0
# P13                2783          2  False             3        0
# P16                3210          9  False            28        1
#
#               cat_nb_hospit  cat_nb_jours_sej  cluster
# CODE_PATIENT
# ...

# %%
p_soins.head()
# Out:
#                    1       2       3       4       5       6       7       8  \
# CODE_PATIENT
# P0            05K051  05M042  05M16T  05M09T  05M092  05C191  05M20Z  05M20Z
# P6            02C05J  02C05J  05M093  04M132  05C222  23M103  04M053     NaN
# P8            11M041     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# P13           05M04T     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# P16           08C11V  23M15Z  05K102  05M08T  05K102  05C191  23M101  05K191
#
#                 9   10  ...  244  245  246  247  248  249  250  251  252  253
# CODE_PATIENT            ...
# P0            NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P6            NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P8            NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# P13           NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
p_soins
# Out:
#                    1       2       3       4       5       6       7       8  \
# CODE_PATIENT
# P0            05K051  05M042  05M16T  05M09T  05M092  05C191  05M20Z  05M20Z
# P6            02C05J  02C05J  05M093  04M132  05C222  23M103  04M053     NaN
# P8            11M041     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# P13           05M04T     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# P16           08C11V  23M15Z  05K102  05M08T  05K102  05C191  23M101  05K191
# ...              ...     ...     ...     ...     ...     ...     ...     ...
# P24302        04M05V  23M20T  05M082  06M033  09M031  05M093  10M182     NaN
# P24303        05M094  05M09T  05K052  23M101  09M053  05C143  23M101  09M053
# P24304           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# P24308        05M091  04M173  04M171  04C042  23M061  07M023     NaN     NaN
# P24310        08C322  08C14J  08C322     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
p_soins.iloc[0][0]
# Out:
# '05K051'

# %%
p_soins.iloc[1][0]
# Out:
# '02C05J'

# %%
source=[]
for p in tqdm(range(1, len(p_soins))):
    i=1
    while p_soins.iloc[p][i] != pd.NaN
    source.append(
