# %%
pip install pywaffle
# Out:
# Collecting pywaffle
#   Downloading pywaffle-1.1.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: matplotlib in /opt/mamba/lib/python3.10/site-packages (from pywaffle) (3.6.3)
# Collecting fontawesomefree
#   Downloading fontawesomefree-6.2.1-py3-none-any.whl (25.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 15.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: contourpy>=1.0.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->pywaffle) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->pywaffle) (0.11.0)
# Requirement already satisfied: numpy>=1.19 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->pywaffle) (1.23.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->pywaffle) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->pywaffle) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->pywaffle) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->pywaffle) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->pywaffle) (22.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/mamba/lib/python3.10/site-packages (from matplotlib->pywaffle) (4.38.0)
# Requirement already satisfied: six>=1.5 in /opt/mamba/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pywaffle) (1.16.0)
# Installing collected packages: fontawesomefree, pywaffle
# Successfully installed fontawesomefree-6.2.1 pywaffle-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from tqdm import tqdm
import matplotlib.pyplot as plt
from  matplotlib.ticker import FuncFormatter
from pywaffle import Waffle

# %%
patients=pd.read_csv("data/profil_patient.csv")

# %%
patients.head()
# Out:
#   CODE_PATIENT     date_h0  y_nais BEN_RES_DPT  BEN_SEX_COD dte_deces   Mort  \
# 0           P0  2011-11-22    1949          11            1       NaN  False
# 1           P6  2013-12-05    1929          14            2   2015-03   True
# 2           P8  2015-07-02    1967          54            2   2015-08   True
# 3          P13  2011-05-19    1959         974            1       NaN  False
# 4          P16  2010-03-18    1947          76            1       NaN  False
#
#    Nb_survie  Nb_hospit   CHOC  Nb_jours_sej  cat_age  cat_nb_hospit  \
# 0       2596          9  False            23        1              1
# 1        456          8  False            51        2              1
# 2         41          3   True            43        0              1
# 3       2783          2  False             3        0              1
# 4       3210          9  False            28        1              1
#
#    cat_nb_jours_sej  cluster
# 0                 1        0
# 1                 1        1
# 2                 1        2
# 3                 0        3
# 4                 1        0

# %%
data=patients.groupby("cluster").count()["CODE_PATIENT"].sort_values(ascending=False)
plt.figure(
    FigureClass=Waffle,
    rows=15,
    columns=20,
    title={
        'label': 'Segmentation de la population de patients par clusters',
        'loc': 'center',
        'fontdict': {
            'fontsize': 10
        }},
    values=data,
    labels=[f"{k} ({int(v / sum(data) * 100)}%)" for k, v in data.items()],  # Legend would not be created without this line
    legend={'title': 'Clusters', 'loc': 'upper left', 'bbox_to_anchor': (1, 1), 'ncol': 2,},
    cmap_name="tab20b"
)
plt.plot()
# Out:
# []
# <Waffle size 640x480 with 1 Axes>

# %%
sns.catplot(data=patients, x="cluster", y="y_nais")

# %%
sns.catplot(data=patients, x="cluster", y="Nb_jours_sej")
